# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pip install scipy
import scipy
# Out:
# ...
#   Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
print("Todas as bibliotecas foram importadas com sucesso!")


print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("SciPy:", scipy.__version__)
# Out:
# Todas as bibliotecas foram importadas com sucesso!
# Pandas: 2.2.3
# NumPy: 2.0.2
# SciPy: 1.13.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Criando um conjunto de dados de exemplo
np.random.seed(42)
dados = np.random.randint(10, 100, 50)  # Conjunto de 50 números inteiros aleatórios entre 10 e 100

# Calculando as estatísticas
media = np.mean(dados)
mediana = np.median(dados)
percentil_25 = np.percentile(dados, 25)
percentil_75 = np.percentile(dados, 75)
quartis = [percentil_25, percentil_75]
decis = [np.percentile(dados, i) for i in range(10, 100, 10)]

# Imprimindo os resultados
print("Média:", media)
print("Mediana:", mediana)
print("Percentil 25:", percentil_25)
print("Percentil 75:", percentil_75)
print("Quartis:", quartis)
print("Decis:", decis)

# Visualizando os dados com gráficos
plt.figure(figsize=(14, 6))

# Histograma com média, mediana e moda
plt.hist(dados, bins=10, alpha=0.6, color='lightblue', edgecolor='black')
plt.axvline(media, color='red', linestyle='--', label=f'Média ({media:.2f})')
plt.axvline(mediana, color='green', linestyle='--', label=f'Mediana ({mediana:.2f})')


# Adicionando as linhas dos percentis
plt.axvline(percentil_25, color='purple', linestyle=':', label=f'Percentil 25 ({percentil_25:.2f})')
plt.axvline(percentil_75, color='orange', linestyle=':', label=f'Percentil 75 ({percentil_75:.2f})')

# Personalização do gráfico
plt.title('Distribuição dos Dados com Estatísticas Descritivas')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.legend()

plt.show()
# Out:
# Média: 56.74
# Mediana: 61.5
# Percentil 25: 31.0
# Percentil 75: 73.0
# Quartis: [np.float64(31.0), np.float64(73.0)]
# Decis: [np.float64(15.700000000000001), np.float64(30.0), np.float64(37.199999999999996), np.float64(54.00000000000001), np.float64(61.5), np.float64(69.0), np.float64(71.0), np.float64(82.4), np.float64(92.4)]

# %%
import numpy as np

# Criando um conjunto de dados de exemplo
dados = np.random.randint(10, 100, 50)  # Conjunto de 50 números inteiros aleatórios entre 10 e 100

# Calculando as estatísticas
amplitude = np.max(dados) - np.min(dados)
variancia = np.var(dados, ddof=1)  # ddof=1 para variância amostral
desvio_padrao = np.std(dados, ddof=1)  # ddof=1 para desvio padrão amostral
erro_padrao = desvio_padrao / np.sqrt(len(dados))
coeficiente_variacao = (desvio_padrao / np.mean(dados)) * 100

# Imprimindo os resultados
print("Amplitude:", amplitude)
print("Variância:", variancia)
print("Desvio Padrão:", desvio_padrao)
print("Erro Padrão:", erro_padrao)
print("Coeficiente de Variação (%):", coeficiente_variacao)
# Out:
# Amplitude: 88
# Variância: 775.9546938775511
# Desvio Padrão: 27.855963344992237
# Erro Padrão: 3.939428115545583
# Coeficiente de Variação (%): 49.198098454595964

# %%
import numpy as np
import matplotlib.pyplot as plt

# Criando um conjunto de dados de exemplo
dados = np.random.randint(10, 100, 50)  # Conjunto de 50 números inteiros aleatórios entre 10 e 100

# Calculando as estatísticas
amplitude = np.max(dados) - np.min(dados)
variancia = np.var(dados, ddof=1)  # ddof=1 para variância amostral
desvio_padrao = np.std(dados, ddof=1)  # ddof=1 para desvio padrão amostral
erro_padrao = desvio_padrao / np.sqrt(len(dados))
coeficiente_variacao = (desvio_padrao / np.mean(dados)) * 100

# Imprimindo os resultados
print("Amplitude:", amplitude)
print("Variância:", variancia)
print("Desvio Padrão:", desvio_padrao)
print("Erro Padrão:", erro_padrao)
print("Coeficiente de Variação (%):", coeficiente_variacao)

# Plotando o histograma
plt.figure(figsize=(14, 6))
plt.hist(dados, bins=10, alpha=0.6, color='lightblue', edgecolor='black')

# Adicionando linhas representando a média e o desvio padrão
media = np.mean(dados)
plt.axvline(media, color='red', linestyle='--', label=f'Média ({media:.2f})')
plt.axvline(media + desvio_padrao, color='orange', linestyle=':', label=f'Média + Desvio Padrão ({media + desvio_padrao:.2f})')
plt.axvline(media - desvio_padrao, color='orange', linestyle=':', label=f'Média - Desvio Padrão ({media - desvio_padrao:.2f})')

# Adicionando legendas e títulos
plt.title('Histograma dos Dados com Média e Desvio Padrão')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.legend()

plt.show()
# Out:
# Amplitude: 89
# Variância: 908.8571428571429
# Desvio Padrão: 30.147257634105674
# Erro Padrão: 4.263466061450807
# Coeficiente de Variação (%): 57.75336711514497

# %%
# %pip install seaborn

import matplotlib.pyplot as plt
import seaborn as sns

# Configurando o estilo dos gráficos
sns.set(style="whitegrid")

# Plotando um boxplot para mostrar a distribuição e os outliers
plt.figure(figsize=(8, 6))
sns.boxplot(data=dados, color='lightgreen')
plt.title('Boxplot dos Dados')
plt.ylabel('Valores')
plt.show()

# Plotando um gráfico de dispersão (scatter plot) para visualizar a variação dos valores
plt.figure(figsize=(10, 6))
plt.scatter(range(len(dados)), dados, color='purple', label='Dados')
plt.axhline(np.mean(dados), color='red', linestyle='--', label=f'Média ({np.mean(dados):.2f})')
plt.title('Gráfico de Dispersão dos Dados')
plt.xlabel('Índice')
plt.ylabel('Valores')
plt.legend()
plt.show()

# Plotando um gráfico de linhas para mostrar a variação dos valores ao longo dos índices
plt.figure(figsize=(12, 6))
plt.plot(dados, marker='o', linestyle='-', color='blue', label='Valores')
plt.axhline(np.mean(dados), color='red', linestyle='--', label=f'Média ({np.mean(dados):.2f})')
plt.fill_between(range(len(dados)), np.mean(dados) - desvio_padrao, np.mean(dados) + desvio_padrao,
                 color='orange', alpha=0.3, label='Desvio Padrão')
plt.title('Gráfico de Linhas com Desvio Padrão')
plt.xlabel('Índice')
plt.ylabel('Valores')
plt.legend()
plt.show()
# Out:
# ...
#      -------------------------------------- 294.9/294.9 kB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Exemplo de dados
dados = ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'C', 'B', 'A']

# Criando um gráfico de contagem (frequência) das categorias
sns.countplot(x=dados)

# Adicionando título e rótulos aos eixos
plt.title('Frequência das Categorias')
plt.xlabel('Categorias')
plt.ylabel('Frequência')

# Mostrando o gráfico
plt.show()

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Criando a tabela de contingência
dados = pd.DataFrame({
    'Ação': [30, 10],
    'Comédia': [20, 40]
}, index=['Masculino', 'Feminino'])

# Calculando o qui-quadrado
chi2, p, dof, expected = chi2_contingency(dados)

print("Valor do qui-quadrado:", chi2)
print("p-valor:", p)
# Out:
# Valor do qui-quadrado: 15.041666666666668
# p-valor: 0.00010516355403363114

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Criando a tabela de contingência com os dados
dados = pd.DataFrame({
    'Ação': [30, 10],
    'Comédia': [20, 40]
}, index=['Masculino', 'Feminino'])

# Plotando o gráfico de barras
dados.plot(kind='bar', stacked=False)
plt.title('Preferência por Tipo de Filme por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Número de Pessoas')
plt.legend(title='Tipo de Filme')
plt.show()
